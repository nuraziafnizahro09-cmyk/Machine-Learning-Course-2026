# %%
# !pip install wandb -qU

# %%
# Log in to your W&B account
import wandb
import random
import math

# %%
import random
import math

# Launch 5 simulated experiments
total_runs = 5
for run in range(total_runs):
  # 1️. Start a new run to track this script
  wandb.init(
      # Set the project where this run will be logged
      project="basic-intro",
      # We pass a run name (otherwise it’ll be randomly assigned, like sunshine-lollypop-10)
      name=f"experiment_{run}",
      # Track hyperparameters and run metadata
      config={
      "learning_rate": 0.02,
      "architecture": "CNN",
      "dataset": "CIFAR-100",
      "epochs": 10,
      })

  # This simple block simulates a training loop logging metrics
  epochs = 10
  offset = random.random() / 5
  for epoch in range(2, epochs):
      acc = 1 - 2 ** -epoch - random.random() / epoch - offset
      loss = 2 ** -epoch + random.random() / epoch + offset

      # 2️. Log metrics from your script to W&B
      wandb.log({"acc": acc, "loss": loss})

  # Mark the run as finished
  wandb.finish()
# Out:
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice:
#  1
# wandb: You chose 'Create a W&B account'
# wandb: Create an account here: https://wandb.ai/authorize?signup=true&ref=models
# wandb: After creating your account, create a new API key and store it securely.
# wandb: Paste your API key and hit enter:
#  ··········
# wandb: ERROR Invalid API key: API key may only contain the letters A-Z, digits and underscores.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice:
#  2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Create a new API key at: https://wandb.ai/authorize?ref=models
# wandb: Store your API key securely and do not share it.
# wandb: Paste your API key and hit enter:
#  ··········
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: nuraziafnizahro09 (nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/wandb/run-20260225_161641-smli0d2f</code>
# Syncing run <strong><a href='https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro/runs/smli0d2f' target="_blank">experiment_0</a></strong> to <a href='https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro' target="_blank">https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro</a>
#  View run at <a href='https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro/runs/smli0d2f' target="_blank">https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro/runs/smli0d2f</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>acc</td><td>▁▄█▇██▇█</td></tr><tr><td>loss</td><td>█▄▃▁▂▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>acc</td><td>0.71398</td></tr><tr><td>loss</td><td>0.22267</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">experiment_0</strong> at: <a href='https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro/runs/smli0d2f' target="_blank">https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro/runs/smli0d2f</a><br> View project at: <a href='https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro' target="_blank">https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260225_161641-smli0d2f/logs</code>
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/wandb/run-20260225_161649-6eadvbi9</code>
# Syncing run <strong><a href='https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro/runs/6eadvbi9' target="_blank">experiment_1</a></strong> to <a href='https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro' target="_blank">https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro</a>
#  View run at <a href='https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro/runs/6eadvbi9' target="_blank">https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro/runs/6eadvbi9</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>acc</td><td>▁▄▇▆▇▇██</td></tr><tr><td>loss</td><td>█▅▃▂▂▁▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>acc</td><td>0.89446</td></tr><tr><td>loss</td><td>0.12648</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">experiment_1</strong> at: <a href='https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro/runs/6eadvbi9' target="_blank">https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro/runs/6eadvbi9</a><br> View project at: <a href='https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro' target="_blank">https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260225_161649-6eadvbi9/logs</code>
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/wandb/run-20260225_161655-1bsk0byc</code>
# Syncing run <strong><a href='https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro/runs/1bsk0byc' target="_blank">experiment_2</a></strong> to <a href='https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro' target="_blank">https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro</a>
#  View run at <a href='https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro/runs/1bsk0byc' target="_blank">https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro/runs/1bsk0byc</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>acc</td><td>▁▇▅▆▇▇██</td></tr><tr><td>loss</td><td>█▅▂▁▁▂▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>acc</td><td>0.90724</td></tr><tr><td>loss</td><td>0.18913</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">experiment_2</strong> at: <a href='https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro/runs/1bsk0byc' target="_blank">https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro/runs/1bsk0byc</a><br> View project at: <a href='https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro' target="_blank">https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260225_161655-1bsk0byc/logs</code>
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/wandb/run-20260225_161704-keu6wif4</code>
# Syncing run <strong><a href='https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro/runs/keu6wif4' target="_blank">experiment_3</a></strong> to <a href='https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro' target="_blank">https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro</a>
#  View run at <a href='https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro/runs/keu6wif4' target="_blank">https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro/runs/keu6wif4</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>acc</td><td>▁▂▇▅█▇██</td></tr><tr><td>loss</td><td>██▅▂▂▂▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>acc</td><td>0.95158</td></tr><tr><td>loss</td><td>0.12598</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">experiment_3</strong> at: <a href='https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro/runs/keu6wif4' target="_blank">https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro/runs/keu6wif4</a><br> View project at: <a href='https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro' target="_blank">https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260225_161704-keu6wif4/logs</code>
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/wandb/run-20260225_161710-wth8psoo</code>
# Syncing run <strong><a href='https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro/runs/wth8psoo' target="_blank">experiment_4</a></strong> to <a href='https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro' target="_blank">https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro</a>
#  View run at <a href='https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro/runs/wth8psoo' target="_blank">https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro/runs/wth8psoo</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>acc</td><td>▁▄▆█▇▇██</td></tr><tr><td>loss</td><td>█▅▄▂▂▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>acc</td><td>0.83328</td></tr><tr><td>loss</td><td>0.17661</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">experiment_4</strong> at: <a href='https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro/runs/wth8psoo' target="_blank">https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro/runs/wth8psoo</a><br> View project at: <a href='https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro' target="_blank">https://wandb.ai/nuraziafnizahro09-sekolah-tinggi-ilmu-komputer-el-rahma/basic-intro</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260225_161710-wth8psoo/logs</code>
